# %% [markdown]
# # <a>Arquivos CSV</a>
#
# COMMA SEPARAAATED VALUES. Arquivinhos com valores separados por vírgulas são onipresentes.
#
# Mas o que pode ser uma alegria rapidamente pode se transformar em horas de transtorno! Fear not, padawan, bora com o Let's Data e Xperiun ver como as coisas são solucionadas no mundo real. Claro que todo e toda DS se depararm com muitas maluquices, mas com algumas dicas facilita chegar do outro lado!

# %%
#!pip install pandas requests

# %%
import csv
import numpy as np
import pandas as pd

# %% [markdown]
# ## <a> Vamos do basicão? </a>
#
# Pandas, o que é isso, ainda não, padawan

# %%
# Comos tratar csv sem utilizar pacote csv nem o pandas
linha_para_tratamento = "5.1, 3.5, 1.4, 0.2,setosa"

linha_para_tratamento
# Out:
# '5.1, 3.5, 1.4, 0.2,setosa'

# %%
linha_para_tratamento.split(',')
# Out:
# ['5.1', ' 3.5', ' 1.4', ' 0.2', 'setosa']

# %%
# Base mais molezinha e onipresente: iris (classificação de orquídeas, tudo muito bucólico)

# Abrindo arquivo em Python, modo leitura
with open('./data/iris.csv', mode='r') as arquivo_csv:
    # Passando o arquivo texto csv para o leitor csv padrão do Python
    # Desse jeito é muuuuuito mais fácil
    leitor_csv = csv.reader(arquivo_csv) 
    
    # Iterando cada linha do python
    for linha in leitor_csv:
        print(linha)
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
# ['5.1', '3.5', '1.4', '0.2', 'setosa']
# ['4.9', '3.0', '1.4', '0.2', 'setosa']
# ['4.7', '3.2', '1.3', '0.2', 'setosa']
# ['4.6', '3.1', '1.5', '0.2', 'setosa']
# ['5.0', '3.6', '1.4', '0.2', 'setosa']
# ['5.4', '3.9', '1.7', '0.4', 'setosa']
# ['4.6', '3.4', '1.4', '0.3', 'setosa']
# ['5.0', '3.4', '1.5', '0.2', 'setosa']
# ['4.4', '2.9', '1.4', '0.2', 'setosa']
# ['4.9', '3.1', '1.5', '0.1', 'setosa']
# ['5.4', '3.7', '1.5', '0.2', 'setosa']
# ['4.8', '3.4', '1.6', '0.2', 'setosa']
# ['4.8', '3.0', '1.4', '0.1', 'setosa']
# ['4.3', '3.0', '1.1', '0.1', 'setosa']
# ['5.8', '4.0', '1.2', '0.2', 'setosa']
# ['5.7', '4.4', '1.5', '0.4', 'setosa']
# ['5.4', '3.9', '1.3', '0.4', 'setosa']
# ['5.1', '3.5', '1.4', '0.3', 'setosa']
# ['5.7', '3.8', '1.7', '0.3', 'setosa']
# ['5.1', '3.8', '1.5', '0.3', 'setosa']
# ['5.4', '3.4', '1.7', '0.2', 'setosa']
# ['5.1', '3.7', '1.5', '0.4', 'setosa']
# ['4.6', '3.6', '1.0', '0.2', 'setosa']
# ['5.1', '3.3', '1.7', '0.5', 'setosa']
# ['4.8', '3.4', '1.9', '0.2', 'setosa']
# ['5.0', '3.0', '1.6', '0.2', 'setosa']
# ['5.0', '3.4', '1.6', '0.4', 'setosa']
# ['5.2', '3.5', '1.5', '0.2', 'setosa']
# ['5.2', '3.4', '1.4', '0.2', 'setosa']
# ['4.7', '3.2', '1.6', '0.2', 'setosa']
# ['4.8', '3.1', '1.6', '0.2', 'setosa']
# ['5.4', '3.4', '1.5', '0.4', 'setosa']
# ['5.2', '4.1', '1.5', '0.1', 'setosa']
# ['5.5', '4.2', '1.4', '0.2', 'setosa']
# ['4.9', '3.1', '1.5', '0.2', 'setosa']
# ['5.0', '3.2', '1.2', '0.2', 'setosa']
# ['5.5', '3.5', '1.3', '0.2', 'setosa']
# ['4.9', '3.6', '1.4', '0.1', 'setosa']
# ['4.4', '3.0', '1.3', '0.2', 'setosa']
# ['5.1', '3.4', '1.5', '0.2', 'setosa']
# ['5.0', '3.5', '1.3', '0.3', 'setosa']
# ['4.5', '2.3', '1.3', '0.3', 'setosa']
# ['4.4', '3.2', '1.3', '0.2', 'setosa']
# ['5.0', '3.5', '1.6', '0.6', 'setosa']
# ['5.1', '3.8', '1.9', '0.4', 'setosa']
# ['4.8', '3.0', '1.4', '0.3', 'setosa']
# ['5.1', '3.8', '1.6', '0.2', 'setosa']
# ['4.6', '3.2', '1.4', '0.2', 'setosa']
# ['5.3', '3.7', '1.5', '0.2', 'setosa']
# ['5.0', '3.3', '1.4', '0.2', 'setosa']
# ['7.0', '3.2', '4.7', '1.4', 'versicolor']
# ['6.4', '3.2', '4.5', '1.5', 'versicolor']
# ['6.9', '3.1', '4.9', '1.5', 'versicolor']
# ['5.5', '2.3', '4.0', '1.3', 'versicolor']
# ['6.5', '2.8', '4.6', '1.5', 'versicolor']
# ['5.7', '2.8', '4.5', '1.3', 'versicolor']
# ['6.3', '3.3', '4.7', '1.6', 'versicolor']
# ['4.9', '2.4', '3.3', '1.0', 'versicolor']
# ['6.6', '2.9', '4.6', '1.3', 'versicolor']
# ['5.2', '2.7', '3.9', '1.4', 'versicolor']
# ['5.0', '2.0', '3.5', '1.0', 'versicolor']
# ['5.9', '3.0', '4.2', '1.5', 'versicolor']
# ['6.0', '2.2', '4.0', '1.0', 'versicolor']
# ['6.1', '2.9', '4.7', '1.4', 'versicolor']
# ['5.6', '2.9', '3.6', '1.3', 'versicolor']
# ['6.7', '3.1', '4.4', '1.4', 'versicolor']
# ['5.6', '3.0', '4.5', '1.5', 'versicolor']
# ['5.8', '2.7', '4.1', '1.0', 'versicolor']
# ['6.2', '2.2', '4.5', '1.5', 'versicolor']
# ['5.6', '2.5', '3.9', '1.1', 'versicolor']
# ['5.9', '3.2', '4.8', '1.8', 'versicolor']
# ['6.1', '2.8', '4.0', '1.3', 'versicolor']
# ['6.3', '2.5', '4.9', '1.5', 'versicolor']
# ['6.1', '2.8', '4.7', '1.2', 'versicolor']
# ['6.4', '2.9', '4.3', '1.3', 'versicolor']
# ['6.6', '3.0', '4.4', '1.4', 'versicolor']
# ['6.8', '2.8', '4.8', '1.4', 'versicolor']
# ['6.7', '3.0', '5.0', '1.7', 'versicolor']
# ['6.0', '2.9', '4.5', '1.5', 'versicolor']
# ['5.7', '2.6', '3.5', '1.0', 'versicolor']
# ['5.5', '2.4', '3.8', '1.1', 'versicolor']
# ['5.5', '2.4', '3.7', '1.0', 'versicolor']
# ['5.8', '2.7', '3.9', '1.2', 'versicolor']
# ['6.0', '2.7', '5.1', '1.6', 'versicolor']
# ['5.4', '3.0', '4.5', '1.5', 'versicolor']
# ['6.0', '3.4', '4.5', '1.6', 'versicolor']
# ['6.7', '3.1', '4.7', '1.5', 'versicolor']
# ['6.3', '2.3', '4.4', '1.3', 'versicolor']
# ['5.6', '3.0', '4.1', '1.3', 'versicolor']
# ['5.5', '2.5', '4.0', '1.3', 'versicolor']
# ['5.5', '2.6', '4.4', '1.2', 'versicolor']
# ['6.1', '3.0', '4.6', '1.4', 'versicolor']
# ['5.8', '2.6', '4.0', '1.2', 'versicolor']
# ['5.0', '2.3', '3.3', '1.0', 'versicolor']
# ['5.6', '2.7', '4.2', '1.3', 'versicolor']
# ['5.7', '3.0', '4.2', '1.2', 'versicolor']
# ['5.7', '2.9', '4.2', '1.3', 'versicolor']
# ['6.2', '2.9', '4.3', '1.3', 'versicolor']
# ['5.1', '2.5', '3.0', '1.1', 'versicolor']
# ['5.7', '2.8', '4.1', '1.3', 'versicolor']
# ['6.3', '3.3', '6.0', '2.5', 'virginica']
# ['5.8', '2.7', '5.1', '1.9', 'virginica']
# ['7.1', '3.0', '5.9', '2.1', 'virginica']
# ['6.3', '2.9', '5.6', '1.8', 'virginica']
# ['6.5', '3.0', '5.8', '2.2', 'virginica']
# ['7.6', '3.0', '6.6', '2.1', 'virginica']
# ['4.9', '2.5', '4.5', '1.7', 'virginica']
# ['7.3', '2.9', '6.3', '1.8', 'virginica']
# ['6.7', '2.5', '5.8', '1.8', 'virginica']
# ['7.2', '3.6', '6.1', '2.5', 'virginica']
# ['6.5', '3.2', '5.1', '2.0', 'virginica']
# ['6.4', '2.7', '5.3', '1.9', 'virginica']
# ['6.8', '3.0', '5.5', '2.1', 'virginica']
# ['5.7', '2.5', '5.0', '2.0', 'virginica']
# ['5.8', '2.8', '5.1', '2.4', 'virginica']
# ['6.4', '3.2', '5.3', '2.3', 'virginica']
# ['6.5', '3.0', '5.5', '1.8', 'virginica']
# ['7.7', '3.8', '6.7', '2.2', 'virginica']
# ['7.7', '2.6', '6.9', '2.3', 'virginica']
# ['6.0', '2.2', '5.0', '1.5', 'virginica']
# ['6.9', '3.2', '5.7', '2.3', 'virginica']
# ['5.6', '2.8', '4.9', '2.0', 'virginica']
# ['7.7', '2.8', '6.7', '2.0', 'virginica']
# ['6.3', '2.7', '4.9', '1.8', 'virginica']
# ['6.7', '3.3', '5.7', '2.1', 'virginica']
# ['7.2', '3.2', '6.0', '1.8', 'virginica']
# ['6.2', '2.8', '4.8', '1.8', 'virginica']
# ['6.1', '3.0', '4.9', '1.8', 'virginica']
# ['6.4', '2.8', '5.6', '2.1', 'virginica']
# ['7.2', '3.0', '5.8', '1.6', 'virginica']
# ['7.4', '2.8', '6.1', '1.9', 'virginica']
# ['7.9', '3.8', '6.4', '2.0', 'virginica']
# ['6.4', '2.8', '5.6', '2.2', 'virginica']
# ['6.3', '2.8', '5.1', '1.5', 'virginica']
# ['6.1', '2.6', '5.6', '1.4', 'virginica']
# ['7.7', '3.0', '6.1', '2.3', 'virginica']
# ['6.3', '3.4', '5.6', '2.4', 'virginica']
# ['6.4', '3.1', '5.5', '1.8', 'virginica']
# ['6.0', '3.0', '4.8', '1.8', 'virginica']
# ['6.9', '3.1', '5.4', '2.1', 'virginica']
# ['6.7', '3.1', '5.6', '2.4', 'virginica']
# ['6.9', '3.1', '5.1', '2.3', 'virginica']
# ['5.8', '2.7', '5.1', '1.9', 'virginica']
# ['6.8', '3.2', '5.9', '2.3', 'virginica']
# ['6.7', '3.3', '5.7', '2.5', 'virginica']
# ['6.7', '3.0', '5.2', '2.3', 'virginica']
# ['6.3', '2.5', '5.0', '1.9', 'virginica']
# ['6.5', '3.0', '5.2', '2.0', 'virginica']
# ['6.2', '3.4', '5.4', '2.3', 'virginica']
# ['5.9', '3.0', '5.1', '1.8', 'virginica']

# %%
# Exemplo enumerate

# Base mais molezinha e onipresente: iris (classificação de orquídeas, tudo muito bucólico)

# Abrindo arquivo em Python, modo leitura
with open('./data/iris.csv', mode='r') as arquivo_csv:
    # Passando o arquivo texto csv para o leitor csv padrão do Python
    # Desse jeito é muuuuuito mais fácil
    leitor_csv = csv.reader(arquivo_csv) 
    
    # Iterando cada linha do python
    for indice, linha in enumerate(leitor_csv):
        print(f'Esta é a {indice+1}a linha: {linha}')
# Out:
# Esta é a 1a linha: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
# Esta é a 2a linha: ['5.1', '3.5', '1.4', '0.2', 'setosa']
# Esta é a 3a linha: ['4.9', '3.0', '1.4', '0.2', 'setosa']
# Esta é a 4a linha: ['4.7', '3.2', '1.3', '0.2', 'setosa']
# Esta é a 5a linha: ['4.6', '3.1', '1.5', '0.2', 'setosa']
# Esta é a 6a linha: ['5.0', '3.6', '1.4', '0.2', 'setosa']
# Esta é a 7a linha: ['5.4', '3.9', '1.7', '0.4', 'setosa']
# Esta é a 8a linha: ['4.6', '3.4', '1.4', '0.3', 'setosa']
# Esta é a 9a linha: ['5.0', '3.4', '1.5', '0.2', 'setosa']
# Esta é a 10a linha: ['4.4', '2.9', '1.4', '0.2', 'setosa']
# Esta é a 11a linha: ['4.9', '3.1', '1.5', '0.1', 'setosa']
# Esta é a 12a linha: ['5.4', '3.7', '1.5', '0.2', 'setosa']
# Esta é a 13a linha: ['4.8', '3.4', '1.6', '0.2', 'setosa']
# Esta é a 14a linha: ['4.8', '3.0', '1.4', '0.1', 'setosa']
# Esta é a 15a linha: ['4.3', '3.0', '1.1', '0.1', 'setosa']
# Esta é a 16a linha: ['5.8', '4.0', '1.2', '0.2', 'setosa']
# Esta é a 17a linha: ['5.7', '4.4', '1.5', '0.4', 'setosa']
# Esta é a 18a linha: ['5.4', '3.9', '1.3', '0.4', 'setosa']
# Esta é a 19a linha: ['5.1', '3.5', '1.4', '0.3', 'setosa']
# Esta é a 20a linha: ['5.7', '3.8', '1.7', '0.3', 'setosa']
# Esta é a 21a linha: ['5.1', '3.8', '1.5', '0.3', 'setosa']
# Esta é a 22a linha: ['5.4', '3.4', '1.7', '0.2', 'setosa']
# Esta é a 23a linha: ['5.1', '3.7', '1.5', '0.4', 'setosa']
# Esta é a 24a linha: ['4.6', '3.6', '1.0', '0.2', 'setosa']
# Esta é a 25a linha: ['5.1', '3.3', '1.7', '0.5', 'setosa']
# Esta é a 26a linha: ['4.8', '3.4', '1.9', '0.2', 'setosa']
# Esta é a 27a linha: ['5.0', '3.0', '1.6', '0.2', 'setosa']
# Esta é a 28a linha: ['5.0', '3.4', '1.6', '0.4', 'setosa']
# Esta é a 29a linha: ['5.2', '3.5', '1.5', '0.2', 'setosa']
# Esta é a 30a linha: ['5.2', '3.4', '1.4', '0.2', 'setosa']
# Esta é a 31a linha: ['4.7', '3.2', '1.6', '0.2', 'setosa']
# Esta é a 32a linha: ['4.8', '3.1', '1.6', '0.2', 'setosa']
# Esta é a 33a linha: ['5.4', '3.4', '1.5', '0.4', 'setosa']
# Esta é a 34a linha: ['5.2', '4.1', '1.5', '0.1', 'setosa']
# Esta é a 35a linha: ['5.5', '4.2', '1.4', '0.2', 'setosa']
# Esta é a 36a linha: ['4.9', '3.1', '1.5', '0.2', 'setosa']
# Esta é a 37a linha: ['5.0', '3.2', '1.2', '0.2', 'setosa']
# Esta é a 38a linha: ['5.5', '3.5', '1.3', '0.2', 'setosa']
# Esta é a 39a linha: ['4.9', '3.6', '1.4', '0.1', 'setosa']
# Esta é a 40a linha: ['4.4', '3.0', '1.3', '0.2', 'setosa']
# Esta é a 41a linha: ['5.1', '3.4', '1.5', '0.2', 'setosa']
# Esta é a 42a linha: ['5.0', '3.5', '1.3', '0.3', 'setosa']
# Esta é a 43a linha: ['4.5', '2.3', '1.3', '0.3', 'setosa']
# Esta é a 44a linha: ['4.4', '3.2', '1.3', '0.2', 'setosa']
# Esta é a 45a linha: ['5.0', '3.5', '1.6', '0.6', 'setosa']
# Esta é a 46a linha: ['5.1', '3.8', '1.9', '0.4', 'setosa']
# Esta é a 47a linha: ['4.8', '3.0', '1.4', '0.3', 'setosa']
# Esta é a 48a linha: ['5.1', '3.8', '1.6', '0.2', 'setosa']
# Esta é a 49a linha: ['4.6', '3.2', '1.4', '0.2', 'setosa']
# Esta é a 50a linha: ['5.3', '3.7', '1.5', '0.2', 'setosa']
# Esta é a 51a linha: ['5.0', '3.3', '1.4', '0.2', 'setosa']
# Esta é a 52a linha: ['7.0', '3.2', '4.7', '1.4', 'versicolor']
# Esta é a 53a linha: ['6.4', '3.2', '4.5', '1.5', 'versicolor']
# Esta é a 54a linha: ['6.9', '3.1', '4.9', '1.5', 'versicolor']
# Esta é a 55a linha: ['5.5', '2.3', '4.0', '1.3', 'versicolor']
# Esta é a 56a linha: ['6.5', '2.8', '4.6', '1.5', 'versicolor']
# Esta é a 57a linha: ['5.7', '2.8', '4.5', '1.3', 'versicolor']
# Esta é a 58a linha: ['6.3', '3.3', '4.7', '1.6', 'versicolor']
# Esta é a 59a linha: ['4.9', '2.4', '3.3', '1.0', 'versicolor']
# Esta é a 60a linha: ['6.6', '2.9', '4.6', '1.3', 'versicolor']
# Esta é a 61a linha: ['5.2', '2.7', '3.9', '1.4', 'versicolor']
# Esta é a 62a linha: ['5.0', '2.0', '3.5', '1.0', 'versicolor']
# Esta é a 63a linha: ['5.9', '3.0', '4.2', '1.5', 'versicolor']
# Esta é a 64a linha: ['6.0', '2.2', '4.0', '1.0', 'versicolor']
# Esta é a 65a linha: ['6.1', '2.9', '4.7', '1.4', 'versicolor']
# Esta é a 66a linha: ['5.6', '2.9', '3.6', '1.3', 'versicolor']
# Esta é a 67a linha: ['6.7', '3.1', '4.4', '1.4', 'versicolor']
# Esta é a 68a linha: ['5.6', '3.0', '4.5', '1.5', 'versicolor']
# Esta é a 69a linha: ['5.8', '2.7', '4.1', '1.0', 'versicolor']
# Esta é a 70a linha: ['6.2', '2.2', '4.5', '1.5', 'versicolor']
# Esta é a 71a linha: ['5.6', '2.5', '3.9', '1.1', 'versicolor']
# Esta é a 72a linha: ['5.9', '3.2', '4.8', '1.8', 'versicolor']
# Esta é a 73a linha: ['6.1', '2.8', '4.0', '1.3', 'versicolor']
# Esta é a 74a linha: ['6.3', '2.5', '4.9', '1.5', 'versicolor']
# Esta é a 75a linha: ['6.1', '2.8', '4.7', '1.2', 'versicolor']
# Esta é a 76a linha: ['6.4', '2.9', '4.3', '1.3', 'versicolor']
# Esta é a 77a linha: ['6.6', '3.0', '4.4', '1.4', 'versicolor']
# Esta é a 78a linha: ['6.8', '2.8', '4.8', '1.4', 'versicolor']
# Esta é a 79a linha: ['6.7', '3.0', '5.0', '1.7', 'versicolor']
# Esta é a 80a linha: ['6.0', '2.9', '4.5', '1.5', 'versicolor']
# Esta é a 81a linha: ['5.7', '2.6', '3.5', '1.0', 'versicolor']
# Esta é a 82a linha: ['5.5', '2.4', '3.8', '1.1', 'versicolor']
# Esta é a 83a linha: ['5.5', '2.4', '3.7', '1.0', 'versicolor']
# Esta é a 84a linha: ['5.8', '2.7', '3.9', '1.2', 'versicolor']
# Esta é a 85a linha: ['6.0', '2.7', '5.1', '1.6', 'versicolor']
# Esta é a 86a linha: ['5.4', '3.0', '4.5', '1.5', 'versicolor']
# Esta é a 87a linha: ['6.0', '3.4', '4.5', '1.6', 'versicolor']
# Esta é a 88a linha: ['6.7', '3.1', '4.7', '1.5', 'versicolor']
# Esta é a 89a linha: ['6.3', '2.3', '4.4', '1.3', 'versicolor']
# Esta é a 90a linha: ['5.6', '3.0', '4.1', '1.3', 'versicolor']
# Esta é a 91a linha: ['5.5', '2.5', '4.0', '1.3', 'versicolor']
# Esta é a 92a linha: ['5.5', '2.6', '4.4', '1.2', 'versicolor']
# Esta é a 93a linha: ['6.1', '3.0', '4.6', '1.4', 'versicolor']
# Esta é a 94a linha: ['5.8', '2.6', '4.0', '1.2', 'versicolor']
# Esta é a 95a linha: ['5.0', '2.3', '3.3', '1.0', 'versicolor']
# Esta é a 96a linha: ['5.6', '2.7', '4.2', '1.3', 'versicolor']
# Esta é a 97a linha: ['5.7', '3.0', '4.2', '1.2', 'versicolor']
# Esta é a 98a linha: ['5.7', '2.9', '4.2', '1.3', 'versicolor']
# Esta é a 99a linha: ['6.2', '2.9', '4.3', '1.3', 'versicolor']
# Esta é a 100a linha: ['5.1', '2.5', '3.0', '1.1', 'versicolor']
# Esta é a 101a linha: ['5.7', '2.8', '4.1', '1.3', 'versicolor']
# Esta é a 102a linha: ['6.3', '3.3', '6.0', '2.5', 'virginica']
# Esta é a 103a linha: ['5.8', '2.7', '5.1', '1.9', 'virginica']
# Esta é a 104a linha: ['7.1', '3.0', '5.9', '2.1', 'virginica']
# Esta é a 105a linha: ['6.3', '2.9', '5.6', '1.8', 'virginica']
# Esta é a 106a linha: ['6.5', '3.0', '5.8', '2.2', 'virginica']
# Esta é a 107a linha: ['7.6', '3.0', '6.6', '2.1', 'virginica']
# Esta é a 108a linha: ['4.9', '2.5', '4.5', '1.7', 'virginica']
# Esta é a 109a linha: ['7.3', '2.9', '6.3', '1.8', 'virginica']
# Esta é a 110a linha: ['6.7', '2.5', '5.8', '1.8', 'virginica']
# Esta é a 111a linha: ['7.2', '3.6', '6.1', '2.5', 'virginica']
# Esta é a 112a linha: ['6.5', '3.2', '5.1', '2.0', 'virginica']
# Esta é a 113a linha: ['6.4', '2.7', '5.3', '1.9', 'virginica']
# Esta é a 114a linha: ['6.8', '3.0', '5.5', '2.1', 'virginica']
# Esta é a 115a linha: ['5.7', '2.5', '5.0', '2.0', 'virginica']
# Esta é a 116a linha: ['5.8', '2.8', '5.1', '2.4', 'virginica']
# Esta é a 117a linha: ['6.4', '3.2', '5.3', '2.3', 'virginica']
# Esta é a 118a linha: ['6.5', '3.0', '5.5', '1.8', 'virginica']
# Esta é a 119a linha: ['7.7', '3.8', '6.7', '2.2', 'virginica']
# Esta é a 120a linha: ['7.7', '2.6', '6.9', '2.3', 'virginica']
# Esta é a 121a linha: ['6.0', '2.2', '5.0', '1.5', 'virginica']
# Esta é a 122a linha: ['6.9', '3.2', '5.7', '2.3', 'virginica']
# Esta é a 123a linha: ['5.6', '2.8', '4.9', '2.0', 'virginica']
# Esta é a 124a linha: ['7.7', '2.8', '6.7', '2.0', 'virginica']
# Esta é a 125a linha: ['6.3', '2.7', '4.9', '1.8', 'virginica']
# Esta é a 126a linha: ['6.7', '3.3', '5.7', '2.1', 'virginica']
# Esta é a 127a linha: ['7.2', '3.2', '6.0', '1.8', 'virginica']
# Esta é a 128a linha: ['6.2', '2.8', '4.8', '1.8', 'virginica']
# Esta é a 129a linha: ['6.1', '3.0', '4.9', '1.8', 'virginica']
# Esta é a 130a linha: ['6.4', '2.8', '5.6', '2.1', 'virginica']
# Esta é a 131a linha: ['7.2', '3.0', '5.8', '1.6', 'virginica']
# Esta é a 132a linha: ['7.4', '2.8', '6.1', '1.9', 'virginica']
# Esta é a 133a linha: ['7.9', '3.8', '6.4', '2.0', 'virginica']
# Esta é a 134a linha: ['6.4', '2.8', '5.6', '2.2', 'virginica']
# Esta é a 135a linha: ['6.3', '2.8', '5.1', '1.5', 'virginica']
# Esta é a 136a linha: ['6.1', '2.6', '5.6', '1.4', 'virginica']
# Esta é a 137a linha: ['7.7', '3.0', '6.1', '2.3', 'virginica']
# Esta é a 138a linha: ['6.3', '3.4', '5.6', '2.4', 'virginica']
# Esta é a 139a linha: ['6.4', '3.1', '5.5', '1.8', 'virginica']
# Esta é a 140a linha: ['6.0', '3.0', '4.8', '1.8', 'virginica']
# Esta é a 141a linha: ['6.9', '3.1', '5.4', '2.1', 'virginica']
# Esta é a 142a linha: ['6.7', '3.1', '5.6', '2.4', 'virginica']
# Esta é a 143a linha: ['6.9', '3.1', '5.1', '2.3', 'virginica']
# Esta é a 144a linha: ['5.8', '2.7', '5.1', '1.9', 'virginica']
# Esta é a 145a linha: ['6.8', '3.2', '5.9', '2.3', 'virginica']
# Esta é a 146a linha: ['6.7', '3.3', '5.7', '2.5', 'virginica']
# Esta é a 147a linha: ['6.7', '3.0', '5.2', '2.3', 'virginica']
# Esta é a 148a linha: ['6.3', '2.5', '5.0', '1.9', 'virginica']
# Esta é a 149a linha: ['6.5', '3.0', '5.2', '2.0', 'virginica']
# Esta é a 150a linha: ['6.2', '3.4', '5.4', '2.3', 'virginica']
# Esta é a 151a linha: ['5.9', '3.0', '5.1', '1.8', 'virginica']

# %%
# Além de iterar num for, posso também utilizar o next() 

cabecalho = None
primeira_linha = None

# Abrindo arquivo em Python, modo leitura
with open('./data/iris.csv', mode='r') as arquivo_csv:
    # Passando o arquivo texto csv para o leitor csv padrão do Python
    leitor_csv = csv.reader(arquivo_csv) 
    
    cabecalho = next(leitor_csv)
    primeira_linha = next(leitor_csv)
    
cabecalho, primeira_linha
# Out:
# (['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'],
#  ['5.1', '3.5', '1.4', '0.2', 'setosa'])

# %% [markdown]
# ## <a> Mas a gente gosta mesmo é do Paaaandas!</a>
#
# A forma mais simples e rápida. read_csv faz milagres!

# %%
# Formato padrão: com vírgulas separandos os valores
pd.read_csv('./data/iris.csv')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_iris = pd.read_csv('./data/iris.csv')

df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Leitura padrão: pandas espera que seja separado por VÍRGULAS!
df_tab = pd.read_csv('./data/airtravel.tsv')

df_tab
# Out:
#    Month\t"1958"\t"1959"\t"1960"
# 0             JAN\t340\t360\t417
# 1             FEB\t318\t342\t391
# 2             MAR\t362\t406\t419
# 3             APR\t348\t396\t461
# 4             MAY\t363\t420\t472
# 5             JUN\t435\t472\t535
# 6             JUL\t491\t548\t622
# 7             AUG\t505\t559\t606
# 8             SEP\t404\t463\t508
# 9             OCT\t359\t407\t461
# 10            NOV\t310\t362\t390
# 11            DEC\t337\t405\t432

# %%
# Tenho que passar EXPLICITAMENTE o separador que é tabulação (\t)
df_tab = pd.read_csv('./data/airtravel.tsv', sep='\t')

df_tab
# Out:
#    Month  1958  1959  1960
# 0    JAN   340   360   417
# 1    FEB   318   342   391
# 2    MAR   362   406   419
# 3    APR   348   396   461
# 4    MAY   363   420   472
# 5    JUN   435   472   535
# 6    JUL   491   548   622
# 7    AUG   505   559   606
# 8    SEP   404   463   508
# 9    OCT   359   407   461
# 10   NOV   310   362   390
# 11   DEC   337   405   432

# %% [markdown]
# ## <a> E arquivos zipados? Pandas é pandas... </a>

# %%
# Sim, funciona direto \o/
pd.read_csv('./data/iris.zip')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
